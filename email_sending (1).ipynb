# %%
import smtplib

# %%
server = smtplib.SMTP_SSL("smtp.gmail.com", 465)

# %%
server.login("mayur.kolki@gmail.com", "Kolki@123")

# %%
server.sendmail("pavan.koushik@bankopen.co","mayur.kolki@bankopen.co", "brother , doing demo testing")

server.quit()

# %%
"mayur.kolki@gmail.com",

# %%
# !pip install pywhatkit

# %%
import pywhatkit
pywhatkit.sendwhatmsg('+919964471947','hi pavan bro , this is demo testing ',22,12)

# %%
# !pip install pyautogui

# %%
import webbrowser
import pyautogui
import time

# %%
person_name = input('Enter The Person Name Whom You Want To Send A Message: ')
my_msg = input('Enter Your Message: ')

# %%
webbrowser.open('https://web.whatsapp.com/')

# %%
time.sleep(10)
print(pyautogui.position())

# %%
# click on search bar
pyautogui.click(1583,27)
pyautogui.typewrite(person_name)

# %%
# click on search bar
pyautogui.click(184,189)
pyautogui.typewrite(person_name)

# %%
time.sleep(5)

# %%
#click on person 
pyautogui.click(163,319)

time.sleep(5)

pyautogui.typewrite(my_msg)

time.sleep(2)
pyautogui.click(1332,692) # click on Send button

# %%
# !pip install selenium

# %%
from selenium import webdriver
from time import sleep

# %%
driver = webdriver.Chrome("C:\Users\mayur\Desktop\wats_python\chromedriver.exe")

driver.get("https://web.whatsapp.com/")
# Out:
#   File "<ipython-input-7-4b76e180c10b>", line 1
#     driver = webdriver.Chrome("C:\Users\mayur\Desktop\wats_python\chromedriver.exe")
#                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# Whatsapp Script to send sheduled messages
# Send Birthday Wishes
# By KAMLESH PANDEY




def reps():
    print("Do you want to send more msg to anyone")
    askUser = input("Press y for Yes and n for No : ")
    if (askUser == 'Y' or askUser == 'y'):
        msg()
    elif (askUser == 'N' or askUser == 'n'):
        print("Thank you see you soon")
    else:
        print("Please Enter Valid option :\n")
        reps()
        
def msg():
    name = input('\nEnter Group/User Name: ')
    message = f'Happy Birthday to you {name}'
    try:
        Count = int(input("Enter the message count: "))
        timing_in_min = int(input("Enter the time in min after which you want to send the wishes: "))
        timing = (timing_in_min)*60

        # Find whom to message
        user = driver.find_element_by_xpath(
            '//span[@title = "{}"]'.format(name))
        user.click()
    except:
        msg()

    sleep(timing)

    # Text Box
    text_box = driver.find_element_by_class_name('_3uMse')

    # Send Button
    for i in range(Count):
        text_box.send_keys(message)
        driver.find_element_by_class_name("_1U1xa").click()
        # print(i)

    reps()
    
msg()

# %%
! pip install apscheduler

# %%
from apscheduler.schedulers.background import BackgroundScheduler


scheduler = BackgroundScheduler()

# Initialize the rest of the application here, or before the scheduler initialization

# %%
from pytz import utc

from apscheduler.schedulers.background import BackgroundScheduler
from apscheduler.jobstores.mongodb import MongoDBJobStore
from apscheduler.jobstores.sqlalchemy import SQLAlchemyJobStore
from apscheduler.executors.pool import ThreadPoolExecutor, ProcessPoolExecutor


jobstores = {
    'mongo': MongoDBJobStore(),
    'default': SQLAlchemyJobStore(url='sqlite:///jobs.sqlite')
}
executors = {
    'default': ThreadPoolExecutor(20),
    'processpool': ProcessPoolExecutor(5)
}
job_defaults = {
    'coalesce': False,
    'max_instances': 3
}
scheduler = BackgroundScheduler(jobstores=jobstores, executors=executors, job_defaults=job_defaults, timezone=utc)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\envs\TensorFlow\lib\site-packages\apscheduler\jobstores\mongodb.py in <module>
#      13 try:
# ---> 14     from bson.binary import Binary
#      15     from pymongo.errors import DuplicateKeyError
#
# ModuleNotFoundError: No module named 'bson'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-62b4a5903fe4> in <module>
#       2
#       3 from apscheduler.schedulers.background import BackgroundScheduler
# ----> 4 from apscheduler.jobstores.mongodb import MongoDBJobStore
#       5 from apscheduler.jobstores.sqlalchemy import SQLAlchemyJobStore
#       6 from apscheduler.executors.pool import ThreadPoolExecutor, ProcessPoolExecutor
#
# ...

# %%
# !pip install schedule

# %%
import schedule
import time

# %%
def sun_schedule():
    print("Hi team data analyst")
    
schedule.every(10).seconds.do(sun_schedule)

while 1:
    schedule.run_pending()
    time.sleep(1)
# Out:
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# Hi team data analyst
# ...
